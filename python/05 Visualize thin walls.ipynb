# %%
# All imports should be in first cell
import cartopy
import importlib
import matplotlib.pyplot as plt
import numpy as np
import ThinWalls

# %%
importlib.reload(ThinWalls)

help(ThinWalls)
# Out:
# Help on module ThinWalls:
#
# NAME
#     ThinWalls
#
# CLASSES
#     GMesh.GMesh(builtins.object)
#         ThinWalls
#     builtins.object
#         Stats
#
#     class Stats(builtins.object)
#      |  Stats(shape, mean=None, min=None, max=None)
#      |
#      |  Container for statistics fields
#      |
#      |  shape - shape of these arrays
#      |  low   - minimum value
#      |  hgh   - maximum value
#      |  ave   - mean value
#      |
#      |  Methods defined here:
#      |
#      |  __copy__(self)
#      |
#      |  __getitem__(self, key)
#      |
#      |  __init__(self, shape, mean=None, min=None, max=None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  __setitem__(self, key, value)
#      |
#      |  copy(self)
#      |      Returns new instance with copied values
#      |
#      |  dump(self)
#      |
#      |  flip(self, axis)
#      |      Flip the data along the given axis
#      |
#      |  max2u(self)
#      |      Return 2d/2-point maximum on u-edges
#      |
#      |  max2v(self)
#      |      Return 2d/2-point maximum on v-edges
#      |
#      |  max4(self)
#      |      Return 2d/4-point maximum
#      |
#      |  mean2u(self)
#      |      Return 2d/2-point mean on u-edges
#      |
#      |  mean2v(self)
#      |      Return 2d/2-point mean on v-edges
#      |
#      |  mean4(self)
#      |      Return 2d/4-point mean
#      |
#      |  min2u(self)
#      |      Return 2d/2-point minimum on u-edges
#      |
#      |  min2v(self)
#      |      Return 2d/2-point minimum on v-edges
#      |
#      |  min4(self)
#      |      Return 2d/4-point minimum
#      |
#      |  set(self, min, max, mean)
#      |
#      |  set_equal(self, values)
#      |
#      |  transpose(self)
#      |      Transpose data swapping i-j indexes
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class ThinWalls(GMesh.GMesh)
#      |  ThinWalls(*args, **kwargs)
#      |
#      |  Container for thin wall topographic data and mesh.
#      |
#      |  Additional members:
#      |  c_simple - elevation statistics of cell, shape (nj,ni)
#      |  u_simple - elevation statistics of western edge of cell, shape (nj,ni+1)
#      |  v_simple - elevation statistics of southern edge of cell, shape (nj+1,nj)
#      |  shapeu  - shape of zu_simple_mean, ie. =(nj,ni+1)
#      |  shapev  - shape of zv_simple_mean, ie. =(nj+1,ni)
#      |
#      |  Extends the GMesh class.
#      |
#      |  Method resolution order:
#      |      ThinWalls
#      |      GMesh.GMesh
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __copy__(self)
#      |
#      |  __init__(self, *args, **kwargs)
#      |      Constructor for ThinWalls.
#      |
#      |  coarsen(self)
#      |
#      |  copy(self)
#      |      Returns new instance with copied values
#      |
#      |  diagnose_EW_pathway(self, measure='effective')
#      |      Returns deepest EW pathway
#      |
#      |  diagnose_EW_pathways(self, measure='effective')
#      |      Returns deepest EW pathway
#      |
#      |  diagnose_NS_pathway(self, measure='effective')
#      |      Returns deepest NS pathway
#      |
#      |  diagnose_NS_pathways(self, measure='effective')
#      |      Returns NS deep pathways
#      |
#      |  diagnose_SW_pathway(self, measure='effective')
#      |      Returns deepest SW pathway
#      |
#      |  diagnose_SW_pathways(self, measure='effective')
#      |      Returns SW deep pathways
#      |
#      |  diagnose_corner_pathways(self, measure='effective')
#      |      Returns deepest corner pathways
#      |
#      |  dump(self)
#      |      Dump Mesh to tty.
#      |
#      |  fold_out_central_ridge_s(self, verbose=False)
#      |      An interior east-west ridge is folded out to the southern outer edges if it
#      |      is the tallest central ridge and the south is the taller half to expand to.
#      |
#      |  fold_out_central_ridges(self, verbose=False)
#      |      Folded out interior ridges to the sides of the coarse cell
#      |
#      |  init_effective_values(self)
#      |      Initialize effective values by setting equal to simple values.
#      |
#      |  invert_exterior_corners(self, verbose=False)
#      |      The deepest exterior corner is expanded to fill the coarse cell
#      |
#      |  limit_NS_EW_connections(self, ns_deepest_connection, ew_deepest_connection)
#      |      Modify outer edges to satisfy NS and EW deepest connections
#      |
#      |  limit_corner_connections(self, sw_deepest_connection, se_deepest_connection, ne_deepest_connection, nw_deepest_connection)
#      |      Modify outer edges to satisfy deepest corner connections
#      |
#      |  lower_tallest_buttress(self, verbose=False)
#      |      Lower tallest barrier to remove buttress
#      |
#      |  plot(self, axis, thickness=0.2, metric='mean', measure='simple', *args, **kwargs)
#      |      Plots ThinWalls data.
#      |
#      |  plot_grid(self, axis, *args, **kwargs)
#      |      Plots ThinWalls mesh.
#      |
#      |  push_corners(self, update_interior_mean_max=True, verbose=False)
#      |      Folds out tallest corners. Acts only on "effective" values.
#      |
#      |      A convex corner within a coarse grid cell can be made into a
#      |      concave corner without changing connectivity across the major
#      |      parts of the cell. The cross-corner connection for the minor
#      |      part of the cell is eliminated.
#      |
#      |  push_corners_sw(self, update_interior_mean_max=True, verbose=False)
#      |      Folds out SW corner is it is the highest ridge. Acts only on "effective" values.
#      |
#      |      A convex corner within a coarse grid cell can be made into a
#      |      concave corner without changing connectivity across the major
#      |      parts of the cell. The cross-corner connection for the minor
#      |      part of the cell is eliminated.
#      |
#      |  refine(self)
#      |      Returns new ThinWalls instance with twice the resolution.
#      |
#      |  set_cell_mean(self, data)
#      |      Set elevation of cell center.
#      |
#      |  set_center_from_corner(self)
#      |      Set elevation of cell centers from corners.
#      |
#      |  set_edge_from_corner(self)
#      |      Set elevation of cell edges from corners.
#      |
#      |  set_edge_mean(self, datau, datav)
#      |      Set elevation of cell edges u,v.
#      |
#      |  set_edge_to_step(self)
#      |      Set elevation of cell edges to step topography.
#      |
#      |  transpose(self)
#      |      Transpose data swapping i-j indexes
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from GMesh.GMesh:
#      |
#      |  __getitem__(self, key)
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  coarsenby2(self, coarser_mesh)
#      |      Set the height for lower level Mesh by coarsening
#      |
#      |  coarsest_resolution(self, mask_idx=[])
#      |      Returns the coarsest resolution at each grid
#      |
#      |  find_nn_uniform_source(self, lon, lat, use_center=True, debug=False)
#      |      Returns the i,j arrays for the indexes of the nearest neighbor centers at (lon,lat) to the self nodes
#      |      The option use_center=True is default so that lon,lat are cell-center coordinates.
#      |
#      |  find_source_spanning_slices(self, lon, lat, debug=False)
#      |      Finds the slice ranges of the cell data, described by lon and lat cell-center coordinates, that span the mesh.
#      |
#      |  interp_center_coords(self, work_in_3d=True)
#      |      Returns interpolated center coordinates from nodes
#      |
#      |  pcolormesh(self, axis, data, **kwargs)
#      |
#      |  project_source_data_onto_target_mesh(self, xs, ys, zs, use_center=True)
#      |      Returns the array on target mesh with values equal to the nearest-neighbor source point data
#      |
#      |  refine_loop(self, src_lon, src_lat, max_stages=32, max_mb=2000, fixed_refine_level=-1, work_in_3d=True, use_center=True, resolution_limit=False, mask_res=[], singularity_radius=0.25, verbose=True)
#      |      Repeatedly refines the mesh until all cells in the source grid are intercepted by mesh nodes.
#      |      Returns a list of the refined meshes starting with parent mesh.
#      |
#      |  refineby2(self, work_in_3d=True)
#      |      Returns new Mesh instance with twice the resolution
#      |
#      |  rotate(self, y_rot=0, z_rot=0)
#      |      Sequentially apply a rotation about the Y-axis and then the Z-axis.
#      |
#      |  source_hits(self, xs, ys, use_center=True, singularity_radius=0.25)
#      |      Returns an mask array of 1's if a cell with center (xs,ys) is intercepted by a node
#      |      on the mesh, 0 if no node falls in a cell
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from GMesh.GMesh:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
# FILE
#     /local2/home/GitHub/thin-wall-topography/python/ThinWalls.py

# %%
TW = ThinWalls.ThinWalls(lon=np.linspace(0,30,7), lat=np.linspace(0,20,6))
np.random.seed(0)
TW.set_cell_mean( np.random.random( (5,6) ) )
TW.set_edge_mean( np.random.random( (5,7) ), np.random.random( (6,6) ) )
# TW.dump()

# %%
ax = plt.subplot(111)
TW.plot(ax);

# %%
ax = plt.subplot(111, projection=cartopy.crs.NearsidePerspective())
im = TW.plot(ax, transform=cartopy.crs.PlateCarree());
plt.colorbar(im, ax=ax);

# %%
TW.set_edge_to_step()
ax = plt.subplot(111)
TW.plot(ax);
