# %%
import GMesh
import math
import netCDF4
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read topo data
# !cp -n /archive/gold/datasets/topography/GEBCO_08_v2.nc .
with netCDF4.Dataset('GEBCO_08_v2.nc') as nc:
    topo_lon = nc.variables['longitude'][:].filled(0.)
    topo_lat = nc.variables['latitude'][:].filled(0.)
    topo_depth = nc.variables['depth'][:,:].filled(0.)
#! cp -n /archive/gold/datasets/topography/GEBCO_2023/GEBCO_2023.nc .
# with netCDF4.Dataset('/archive/gold/datasets/topography/GEBCO_2023/GEBCO_2023.nc') as nc:
#     topo_lon = nc.variables['lon'][:].filled(0.)
#     topo_lat = nc.variables['lat'][:].filled(0.)
#     topo_depth = nc.variables['elevation'][:,:].filled(0.)

# %%
print(topo_lon.min(), topo_lon.max(), topo_lat.min(), topo_lat.max())
# Out:
# -179.99583333333334 179.99583333333334 -89.99583333333334 89.99583333333334

# %%
def convol( levels, h, f, verbose=False ):
    """Coarsens the product of h*f across all levels"""
    levels[-1].height = ( h * f ).reshape(levels[-1].nj,levels[-1].ni)
    for k in range( len(levels) - 1, 0, -1 ):
        if verbose: print('Coarsening {} -> {}'.format(k,k-1))
        levels[k].coarsenby2( levels[k-1] )
    return levels[0].height

# %%
def rough( levels, h, h2min=1.e-7 ):
    """Calculates both mean of H, and variance of H relative to a plane"""
    # Construction weights for momenet calculations
    nx = 2**( len(levels) - 1 )
    x = ( np.arange(nx) - ( nx - 1 ) /2 ) * np.sqrt( 12 / ( nx**2 - 1 ) )
    X, Y = np.meshgrid( x, x )
    X, Y = X.reshape(1,nx,1,nx), Y.reshape(1,nx,1,nx)
    h = h.reshape(levels[0].nj,nx,levels[0].ni,nx)
    H2 = convol( levels, h, h )
    HX = convol( levels, h, X )
    HY = convol( levels, h, Y )
    H = convol( levels, h, np.ones((1,nx,1,nx)) )
    return H, H2 - H**2 - HX**2 - HY**2 + h2min

# %%
import importlib
importlib.reload(GMesh)
# Out:
# <module 'GMesh' from '/local2/home/GitHub/thin-wall-topography/python/GMesh.py'>

# %%
# Read target mesh
with netCDF4.Dataset('/local2/home/GitHub/OM4_025-grid-data/ocean_hgrid.nc') as nc:
    fullG = GMesh.GMesh( lon=nc.variables['x'][::2,::2], lat=nc.variables['y'][::2,::2] )

# %%
di, dj = fullG.ni // 3, fullG.nj // 45
print('window size dj,di =',dj,di,'full model nj,ni=',fullG.nj, fullG.ni)
Hcnt = np.zeros((fullG.nj, fullG.ni)) # Diagnostic: counting which cells we are working on
Htarg, H2targ = np.zeros((fullG.nj, fullG.ni)), np.zeros((fullG.nj, fullG.ni))
gtic = GMesh.GMesh._toc(None,"")
for j in range( fullG.nj // dj ): # 13
    csj, sj = slice( j*dj, (j+1)*dj ), slice( j*dj, (j+1)*dj+1 )
    print('sj=',sj,'csj=',csj)
    for i in range( fullG.ni // di ): # 4
        csi, si = slice( i*di, (i+1)*di ), slice( i*di, (i+1)*di+1 )
        print('si=',si,'csi=',csi)
        Hcnt[csj,csi] = Hcnt[csj,csi] + 1 # Diagnostic: counting which cells we are working on
        G = GMesh.GMesh( lon = fullG.lon[sj,si], lat = fullG.lat[sj,si] )
        print(j, i, G, G.lon.min(), G.lon.max(), G.lat.min(), G.lat.max())
        # This subsets the source topography so we don't work with too large arrays
        tslices = G.find_source_spanning_slices( topo_lon, topo_lat )
        print('topo slices =', tslices)
        # This recusrively refine the mesh until some criteria is met ...
        levels = G.refine_loop( topo_lon[tslices[0]], topo_lat[tslices[1]], resolution_limit=False, fixed_refine_level=5 )
        # Use nearest neighbor topography to populate the finest grid
        levels[-1].project_source_data_onto_target_mesh( topo_lon[tslices[0]], topo_lat[tslices[1]], topo_depth[tslices[1],tslices[0]] )
        # Now recursively coarsen
        h, h2 = rough( levels, levels[-1].height )
        # Store window in final array
        Htarg[csj,csi] = h
        H2targ[csj,csi] = h2
GMesh.GMesh._toc(gtic,"Whole workflow")
print( Hcnt.min(), Hcnt.max(), '<-- should both be 1 for full model' )
# Out:
# window size dj,di = 24 480 full model nj,ni= 1080 1440
# sj= slice(0, 25, None) csj= slice(0, 24, None)
# si= slice(0, 481, None) csi= slice(0, 480, None)
# 0 0 <GMesh nj:24 ni:480 shape:(24,480)> -299.99458164885345 -180.02607218723773 -80.91667601006795 -78.34532374100719
# topo slices = (slice(28801, 43198, None), slice(1089, 1398, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(480, 961, None) csi= slice(480, 960, None)
# 0 1 <GMesh nj:24 ni:480 shape:(24,480)> -180.79584645537295 -59.36279393959914 -81.66101694915254 -78.59233025247781
# topo slices = (slice(0, 43198, None), slice(1000, 1368, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(960, 1441, None) csi= slice(960, 1440, None)
# 0 2 <GMesh nj:24 ni:480 shape:(24,480)> -59.979340789284386 60.163759721431035 -81.45422729475428 -78.3581420517474
# topo slices = (slice(14402, 28820, None), slice(1025, 1397, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# sj= slice(24, 49, None) csj= slice(24, 48, None)
# si= slice(0, 481, None) csi= slice(0, 480, None)
# 1 0 <GMesh nj:24 ni:480 shape:(24,480)> -300.0 -180.0 -78.59233025247781 -76.17701682224757
# topo slices = (slice(0, 43200, None), slice(1368, 1658, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(480, 961, None) csi= slice(480, 960, None)
# 1 1 <GMesh nj:24 ni:480 shape:(24,480)> -180.02607218723773 -59.979340789284386 -78.76325088339223 -76.17701682224757
# topo slices = (slice(0, 43200, None), slice(1348, 1658, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(960, 1441, None) csi= slice(960, 1440, None)
# 1 2 <GMesh nj:24 ni:480 shape:(24,480)> -60.00000000000077 60.00541835114655 -78.71510309716757 -76.17701682224757
# topo slices = (slice(14400, 28801, None), slice(1354, 1658, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# sj= slice(48, 73, None) csj= slice(48, 72, None)
# si= slice(0, 481, None) csi= slice(0, 480, None)
# 2 0 <GMesh nj:24 ni:480 shape:(24,480)> -300.0 -180.0 -76.17701682224757 -73.74637258524432
# topo slices = (slice(0, 43171, None), slice(1658, 1950, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(480, 961, None) csi= slice(480, 960, None)
# 2 1 <GMesh nj:24 ni:480 shape:(24,480)> -180.0 -60.0 -76.17701682224757 -73.74637258524432
# topo slices = (slice(0, 14401, None), slice(1658, 1950, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(960, 1441, None) csi= slice(960, 1440, None)
# 2 2 <GMesh nj:24 ni:480 shape:(24,480)> -60.0 60.0 -76.17701682224757 -73.74637258524432
# topo slices = (slice(14400, 28801, None), slice(1658, 1950, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# sj= slice(72, 97, None) csj= slice(72, 96, None)
# si= slice(0, 481, None) csi= slice(0, 480, None)
# 3 0 <GMesh nj:24 ni:480 shape:(24,480)> -300.0 -180.0 -73.74637258524432 -71.31572834824107
# topo slices = (slice(0, 43171, None), slice(1950, 2242, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(480, 961, None) csi= slice(480, 960, None)
# 3 1 <GMesh nj:24 ni:480 shape:(24,480)> -180.0 -60.0 -73.74637258524432 -71.31572834824107
# topo slices = (slice(0, 14401, None), slice(1950, 2242, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(960, 1441, None) csi= slice(960, 1440, None)
# 3 2 <GMesh nj:24 ni:480 shape:(24,480)> -60.0 60.0 -73.74637258524432 -71.31572834824107
# topo slices = (slice(14400, 28801, None), slice(1950, 2242, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# sj= slice(96, 121, None) csj= slice(96, 120, None)
# si= slice(0, 481, None) csi= slice(0, 480, None)
# 4 0 <GMesh nj:24 ni:480 shape:(24,480)> -300.0 -180.0 -71.31572834824107 -68.88508411123782
# topo slices = (slice(0, 43171, None), slice(2242, 2533, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(480, 961, None) csi= slice(480, 960, None)
# 4 1 <GMesh nj:24 ni:480 shape:(24,480)> -180.0 -60.0 -71.31572834824107 -68.88508411123782
# topo slices = (slice(0, 14401, None), slice(2242, 2533, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(960, 1441, None) csi= slice(960, 1440, None)
# 4 2 <GMesh nj:24 ni:480 shape:(24,480)> -60.0 60.0 -71.31572834824107 -68.88508411123782
# topo slices = (slice(14400, 28801, None), slice(2242, 2533, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# sj= slice(120, 145, None) csj= slice(120, 144, None)
# si= slice(0, 481, None) csi= slice(0, 480, None)
# 5 0 <GMesh nj:24 ni:480 shape:(24,480)> -300.0 -180.0 -68.88508411123782 -66.46339347431048
# topo slices = (slice(0, 43171, None), slice(2533, 2824, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(480, 961, None) csi= slice(480, 960, None)
# 5 1 <GMesh nj:24 ni:480 shape:(24,480)> -180.0 -60.0 -68.88508411123782 -66.46339347431048
# topo slices = (slice(0, 14401, None), slice(2533, 2824, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(960, 1441, None) csi= slice(960, 1440, None)
# 5 2 <GMesh nj:24 ni:480 shape:(24,480)> -60.0 60.0 -68.88508411123782 -66.46339347431048
# topo slices = (slice(14400, 28801, None), slice(2533, 2824, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# sj= slice(144, 169, None) csj= slice(144, 168, None)
# si= slice(0, 481, None) csi= slice(0, 480, None)
# 6 0 <GMesh nj:24 ni:480 shape:(24,480)> -300.0 -180.0 -66.46339347431048 -63.949383460301405
# topo slices = (slice(0, 43171, None), slice(2824, 3126, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(480, 961, None) csi= slice(480, 960, None)
# 6 1 <GMesh nj:24 ni:480 shape:(24,480)> -180.0 -60.0 -66.46339347431048 -63.949383460301405
# topo slices = (slice(0, 14401, None), slice(2824, 3126, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(960, 1441, None) csi= slice(960, 1440, None)
# 6 2 <GMesh nj:24 ni:480 shape:(24,480)> -60.0 60.0 -66.46339347431048 -63.949383460301405
# topo slices = (slice(14400, 28801, None), slice(2824, 3126, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# sj= slice(168, 193, None) csj= slice(168, 192, None)
# si= slice(0, 481, None) csi= slice(0, 480, None)
# 7 0 <GMesh nj:24 ni:480 shape:(24,480)> -300.0 -180.0 -63.949383460301405 -61.1875073342589
# topo slices = (slice(0, 43171, None), slice(3126, 3457, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(480, 961, None) csi= slice(480, 960, None)
# 7 1 <GMesh nj:24 ni:480 shape:(24,480)> -180.0 -60.0 -63.949383460301405 -61.1875073342589
# topo slices = (slice(0, 14401, None), slice(3126, 3457, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(960, 1441, None) csi= slice(960, 1440, None)
# 7 2 <GMesh nj:24 ni:480 shape:(24,480)> -60.0 60.0 -63.949383460301405 -61.1875073342589
# topo slices = (slice(14400, 28801, None), slice(3126, 3457, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# sj= slice(192, 217, None) csj= slice(192, 216, None)
# si= slice(0, 481, None) csi= slice(0, 480, None)
# 8 0 <GMesh nj:24 ni:480 shape:(24,480)> -300.0 -180.0 -61.1875073342589 -58.160400399775966
# topo slices = (slice(0, 43171, None), slice(3457, 3820, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(480, 961, None) csi= slice(480, 960, None)
# 8 1 <GMesh nj:24 ni:480 shape:(24,480)> -180.0 -60.0 -61.1875073342589 -58.160400399775966
# topo slices = (slice(0, 14401, None), slice(3457, 3820, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(960, 1441, None) csi= slice(960, 1440, None)
# 8 2 <GMesh nj:24 ni:480 shape:(24,480)> -60.0 60.0 -61.1875073342589 -58.160400399775966
# topo slices = (slice(14400, 28801, None), slice(3457, 3820, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# sj= slice(216, 241, None) csj= slice(216, 240, None)
# si= slice(0, 481, None) csi= slice(0, 480, None)
# 9 0 <GMesh nj:24 ni:480 shape:(24,480)> -300.0 -180.0 -58.160400399775966 -54.85187746302786
# topo slices = (slice(0, 43171, None), slice(3820, 4217, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(480, 961, None) csi= slice(480, 960, None)
# 9 1 <GMesh nj:24 ni:480 shape:(24,480)> -180.0 -60.0 -58.160400399775966 -54.85187746302786
# topo slices = (slice(0, 14401, None), slice(3820, 4217, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(960, 1441, None) csi= slice(960, 1440, None)
# 9 2 <GMesh nj:24 ni:480 shape:(24,480)> -60.0 60.0 -58.160400399775966 -54.85187746302786
# topo slices = (slice(14400, 28801, None), slice(3820, 4217, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# sj= slice(240, 265, None) csj= slice(240, 264, None)
# si= slice(0, 481, None) csi= slice(0, 480, None)
# 10 0 <GMesh nj:24 ni:480 shape:(24,480)> -300.0 -180.0 -54.85187746302786 -51.24785751913688
# topo slices = (slice(0, 43171, None), slice(4217, 4650, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(480, 961, None) csi= slice(480, 960, None)
# 10 1 <GMesh nj:24 ni:480 shape:(24,480)> -180.0 -60.0 -54.85187746302786 -51.24785751913688
# topo slices = (slice(0, 14401, None), slice(4217, 4650, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(960, 1441, None) csi= slice(960, 1440, None)
# 10 2 <GMesh nj:24 ni:480 shape:(24,480)> -60.0 60.0 -54.85187746302786 -51.24785751913688
# topo slices = (slice(14400, 28801, None), slice(4217, 4650, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# sj= slice(264, 289, None) csj= slice(264, 288, None)
# si= slice(0, 481, None) csi= slice(0, 480, None)
# 11 0 <GMesh nj:24 ni:480 shape:(24,480)> -300.0 -180.0 -51.24785751913688 -47.3374991205218
# topo slices = (slice(0, 43171, None), slice(4650, 5119, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(480, 961, None) csi= slice(480, 960, None)
# 11 1 <GMesh nj:24 ni:480 shape:(24,480)> -180.0 -60.0 -51.24785751913688 -47.3374991205218
# topo slices = (slice(0, 14401, None), slice(4650, 5119, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(960, 1441, None) csi= slice(960, 1440, None)
# 11 2 <GMesh nj:24 ni:480 shape:(24,480)> -60.0 60.0 -51.24785751913688 -47.3374991205218
# topo slices = (slice(14400, 28801, None), slice(4650, 5119, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# sj= slice(288, 313, None) csj= slice(288, 312, None)
# si= slice(0, 481, None) csi= slice(0, 480, None)
# 12 0 <GMesh nj:24 ni:480 shape:(24,480)> -300.0 -180.0 -47.3374991205218 -43.11452909266513
# topo slices = (slice(0, 43171, None), slice(5119, 5626, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(480, 961, None) csi= slice(480, 960, None)
# 12 1 <GMesh nj:24 ni:480 shape:(24,480)> -180.0 -60.0 -47.3374991205218 -43.11452909266513
# topo slices = (slice(0, 14401, None), slice(5119, 5626, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(960, 1441, None) csi= slice(960, 1440, None)
# 12 2 <GMesh nj:24 ni:480 shape:(24,480)> -60.0 60.0 -47.3374991205218 -43.11452909266513
# topo slices = (slice(14400, 28801, None), slice(5119, 5626, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# sj= slice(312, 337, None) csj= slice(312, 336, None)
# si= slice(0, 481, None) csi= slice(0, 480, None)
# 13 0 <GMesh nj:24 ni:480 shape:(24,480)> -300.0 -180.0 -43.11452909266513 -38.57870911112502
# topo slices = (slice(0, 43171, None), slice(5626, 6170, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(480, 961, None) csi= slice(480, 960, None)
# 13 1 <GMesh nj:24 ni:480 shape:(24,480)> -180.0 -60.0 -43.11452909266513 -38.57870911112502
# topo slices = (slice(0, 14401, None), slice(5626, 6170, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(960, 1441, None) csi= slice(960, 1440, None)
# 13 2 <GMesh nj:24 ni:480 shape:(24,480)> -60.0 60.0 -43.11452909266513 -38.57870911112502
# topo slices = (slice(14400, 28801, None), slice(5626, 6170, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# sj= slice(336, 361, None) csj= slice(336, 360, None)
# si= slice(0, 481, None) csi= slice(0, 480, None)
# 14 0 <GMesh nj:24 ni:480 shape:(24,480)> -300.0 -180.0 -38.57870911112502 -33.73733427701821
# topo slices = (slice(0, 43171, None), slice(6170, 6751, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(480, 961, None) csi= slice(480, 960, None)
# 14 1 <GMesh nj:24 ni:480 shape:(24,480)> -180.0 -60.0 -38.57870911112502 -33.73733427701821
# topo slices = (slice(0, 14401, None), slice(6170, 6751, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(960, 1441, None) csi= slice(960, 1440, None)
# 14 2 <GMesh nj:24 ni:480 shape:(24,480)> -60.0 60.0 -38.57870911112502 -33.73733427701821
# topo slices = (slice(14400, 28801, None), slice(6170, 6751, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# sj= slice(360, 385, None) csj= slice(360, 384, None)
# si= slice(0, 481, None) csi= slice(0, 480, None)
# 15 0 <GMesh nj:24 ni:480 shape:(24,480)> -300.0 -180.0 -33.73733427701821 -28.606600836801938
# topo slices = (slice(0, 43171, None), slice(6751, 7367, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(480, 961, None) csi= slice(480, 960, None)
# 15 1 <GMesh nj:24 ni:480 shape:(24,480)> -180.0 -60.0 -33.73733427701821 -28.606600836801938
# topo slices = (slice(0, 14401, None), slice(6751, 7367, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(960, 1441, None) csi= slice(960, 1440, None)
# 15 2 <GMesh nj:24 ni:480 shape:(24,480)> -60.0 60.0 -33.73733427701821 -28.606600836801938
# topo slices = (slice(14400, 28801, None), slice(6751, 7367, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# sj= slice(384, 409, None) csj= slice(384, 408, None)
# si= slice(0, 481, None) csi= slice(0, 480, None)
# 16 0 <GMesh nj:24 ni:480 shape:(24,480)> -300.0 -180.0 -28.606600836801938 -23.212628925222425
# topo slices = (slice(0, 43171, None), slice(7367, 8014, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(480, 961, None) csi= slice(480, 960, None)
# 16 1 <GMesh nj:24 ni:480 shape:(24,480)> -180.0 -60.0 -28.606600836801938 -23.212628925222425
# topo slices = (slice(0, 14401, None), slice(7367, 8014, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(960, 1441, None) csi= slice(960, 1440, None)
# 16 2 <GMesh nj:24 ni:480 shape:(24,480)> -60.0 60.0 -28.606600836801938 -23.212628925222425
# topo slices = (slice(14400, 28801, None), slice(7367, 8014, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# sj= slice(408, 433, None) csj= slice(408, 432, None)
# si= slice(0, 481, None) csi= slice(0, 480, None)
# 17 0 <GMesh nj:24 ni:480 shape:(24,480)> -300.0 -180.0 -23.212628925222425 -17.59189960153119
# topo slices = (slice(0, 43171, None), slice(8014, 8688, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(480, 961, None) csi= slice(480, 960, None)
# 17 1 <GMesh nj:24 ni:480 shape:(24,480)> -180.0 -60.0 -23.212628925222425 -17.59189960153119
# topo slices = (slice(0, 14401, None), slice(8014, 8688, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(960, 1441, None) csi= slice(960, 1440, None)
# 17 2 <GMesh nj:24 ni:480 shape:(24,480)> -60.0 60.0 -23.212628925222425 -17.59189960153119
# topo slices = (slice(14400, 28801, None), slice(8014, 8688, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# sj= slice(432, 457, None) csj= slice(432, 456, None)
# si= slice(0, 481, None) csi= slice(0, 480, None)
# 18 0 <GMesh nj:24 ni:480 shape:(24,480)> -300.0 -180.0 -17.59189960153119 -11.790885031963947
# topo slices = (slice(0, 43171, None), slice(8688, 9385, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(480, 961, None) csi= slice(480, 960, None)
# 18 1 <GMesh nj:24 ni:480 shape:(24,480)> -180.0 -60.0 -17.59189960153119 -11.790885031963947
# topo slices = (slice(0, 14401, None), slice(8688, 9385, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(960, 1441, None) csi= slice(960, 1440, None)
# 18 2 <GMesh nj:24 ni:480 shape:(24,480)> -60.0 60.0 -17.59189960153119 -11.790885031963947
# topo slices = (slice(14400, 28801, None), slice(8688, 9385, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# sj= slice(456, 481, None) csj= slice(456, 480, None)
# si= slice(0, 481, None) csi= slice(0, 480, None)
# 19 0 <GMesh nj:24 ni:480 shape:(24,480)> -300.0 -180.0 -11.790885031963947 -5.864731960537716
# topo slices = (slice(0, 43171, None), slice(9385, 10096, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(480, 961, None) csi= slice(480, 960, None)
# 19 1 <GMesh nj:24 ni:480 shape:(24,480)> -180.0 -60.0 -11.790885031963947 -5.864731960537716
# topo slices = (slice(0, 14401, None), slice(9385, 10096, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(960, 1441, None) csi= slice(960, 1440, None)
# 19 2 <GMesh nj:24 ni:480 shape:(24,480)> -60.0 60.0 -11.790885031963947 -5.864731960537716
# topo slices = (slice(14400, 28801, None), slice(9385, 10096, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# sj= slice(480, 505, None) csj= slice(480, 504, None)
# si= slice(0, 481, None) csi= slice(0, 480, None)
# 20 0 <GMesh nj:24 ni:480 shape:(24,480)> -300.0 -180.0 -5.864731960537716 0.12499990084080814
# topo slices = (slice(0, 43171, None), slice(10096, 10814, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(480, 961, None) csi= slice(480, 960, None)
# 20 1 <GMesh nj:24 ni:480 shape:(24,480)> -180.0 -60.0 -5.864731960537716 0.12499990084080814
# topo slices = (slice(0, 14401, None), slice(10096, 10814, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(960, 1441, None) csi= slice(960, 1440, None)
# 20 2 <GMesh nj:24 ni:480 shape:(24,480)> -60.0 60.0 -5.864731960537716 0.12499990084080814
# topo slices = (slice(14400, 28801, None), slice(10096, 10814, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# sj= slice(504, 529, None) csj= slice(504, 528, None)
# si= slice(0, 481, None) csi= slice(0, 480, None)
# 21 0 <GMesh nj:24 ni:480 shape:(24,480)> -300.0 -180.0 0.12499990084080814 6.113367224842993
# topo slices = (slice(0, 43171, None), slice(10814, 11533, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(480, 961, None) csi= slice(480, 960, None)
# 21 1 <GMesh nj:24 ni:480 shape:(24,480)> -180.0 -60.0 0.12499990084080814 6.113367224842993
# topo slices = (slice(0, 14401, None), slice(10814, 11533, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(960, 1441, None) csi= slice(960, 1440, None)
# 21 2 <GMesh nj:24 ni:480 shape:(24,480)> -60.0 60.0 0.12499990084080814 6.113367224842993
# topo slices = (slice(14400, 28801, None), slice(10814, 11533, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# sj= slice(528, 553, None) csj= slice(528, 552, None)
# si= slice(0, 481, None) csi= slice(0, 480, None)
# 22 0 <GMesh nj:24 ni:480 shape:(24,480)> -300.0 -180.0 6.113367224842993 12.03550019957427
# topo slices = (slice(0, 43171, None), slice(11533, 12244, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(480, 961, None) csi= slice(480, 960, None)
# 22 1 <GMesh nj:24 ni:480 shape:(24,480)> -180.0 -60.0 6.113367224842993 12.03550019957427
# topo slices = (slice(0, 14401, None), slice(11533, 12244, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(960, 1441, None) csi= slice(960, 1440, None)
# 22 2 <GMesh nj:24 ni:480 shape:(24,480)> -60.0 60.0 6.113367224842993 12.03550019957427
# topo slices = (slice(14400, 28801, None), slice(11533, 12244, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# sj= slice(552, 577, None) csj= slice(552, 576, None)
# si= slice(0, 481, None) csi= slice(0, 480, None)
# 23 0 <GMesh nj:24 ni:480 shape:(24,480)> -300.0 -180.0 12.03550019957427 17.830050201828744
# topo slices = (slice(0, 43171, None), slice(12244, 12939, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(480, 961, None) csi= slice(480, 960, None)
# 23 1 <GMesh nj:24 ni:480 shape:(24,480)> -180.0 -60.0 12.03550019957427 17.830050201828744
# topo slices = (slice(0, 14401, None), slice(12244, 12939, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(960, 1441, None) csi= slice(960, 1440, None)
# 23 2 <GMesh nj:24 ni:480 shape:(24,480)> -60.0 60.0 12.03550019957427 17.830050201828744
# topo slices = (slice(14400, 28801, None), slice(12244, 12939, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# sj= slice(576, 601, None) csj= slice(576, 600, None)
# si= slice(0, 481, None) csi= slice(0, 480, None)
# 24 0 <GMesh nj:24 ni:480 shape:(24,480)> -300.0 -180.0 17.830050201828744 23.44219297525836
# topo slices = (slice(0, 43171, None), slice(12939, 13613, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(480, 961, None) csi= slice(480, 960, None)
# 24 1 <GMesh nj:24 ni:480 shape:(24,480)> -180.0 -60.0 17.830050201828744 23.44219297525836
# topo slices = (slice(0, 14401, None), slice(12939, 13613, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(960, 1441, None) csi= slice(960, 1440, None)
# 24 2 <GMesh nj:24 ni:480 shape:(24,480)> -60.0 60.0 17.830050201828744 23.44219297525836
# topo slices = (slice(14400, 28801, None), slice(12939, 13613, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# sj= slice(600, 625, None) csj= slice(600, 624, None)
# si= slice(0, 481, None) csi= slice(0, 480, None)
# 25 0 <GMesh nj:24 ni:480 shape:(24,480)> -300.0 -180.0 23.44219297525836 28.825853153291956
# topo slices = (slice(0, 43171, None), slice(13613, 14259, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(480, 961, None) csi= slice(480, 960, None)
# 25 1 <GMesh nj:24 ni:480 shape:(24,480)> -180.0 -60.0 23.44219297525836 28.825853153291956
# topo slices = (slice(0, 14401, None), slice(13613, 14259, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# ...
# 36 2 <GMesh nj:24 ni:480 shape:(24,480)> -60.651426879154116 60.0 64.0589597296948 69.24716778375586
# topo slices = (slice(14321, 28801, None), slice(18487, 19109, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# sj= slice(888, 913, None) csj= slice(888, 912, None)
# si= slice(0, 481, None) csi= slice(0, 480, None)
# 37 0 <GMesh nj:24 ni:480 shape:(24,480)> -300.0 -178.35217332071 64.0589597296948 71.84127181078637
# topo slices = (slice(0, 43200, None), slice(18487, 19420, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(480, 961, None) csi= slice(480, 960, None)
# 37 1 <GMesh nj:24 ni:480 shape:(24,480)> -179.34857312084588 -60.651426879154116 64.0589597296948 70.87969672497411
# topo slices = (slice(78, 14322, None), slice(18487, 19305, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(960, 1441, None) csi= slice(960, 1440, None)
# 37 2 <GMesh nj:24 ni:480 shape:(24,480)> -61.647826679290006 60.0 64.0589597296948 71.84127181078637
# topo slices = (slice(14202, 28801, None), slice(18487, 19420, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# sj= slice(912, 937, None) csj= slice(912, 936, None)
# si= slice(0, 481, None) csi= slice(0, 480, None)
# 38 0 <GMesh nj:24 ni:480 shape:(24,480)> -300.0 -176.6633686070852 64.0589597296948 74.43537583781688
# topo slices = (slice(0, 43198, None), slice(18487, 19732, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(480, 961, None) csi= slice(480, 960, None)
# 38 1 <GMesh nj:24 ni:480 shape:(24,480)> -178.35217332071 -61.647826679290006 64.0589597296948 73.15181489204586
# topo slices = (slice(197, 14203, None), slice(18487, 19578, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(960, 1441, None) csi= slice(960, 1440, None)
# 38 2 <GMesh nj:24 ni:480 shape:(24,480)> -63.336631392914796 60.0 64.0589597296948 74.43537583781688
# topo slices = (slice(13999, 28801, None), slice(18487, 19732, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# sj= slice(936, 961, None) csj= slice(936, 960, None)
# si= slice(0, 481, None) csi= slice(0, 480, None)
# 39 0 <GMesh nj:24 ni:480 shape:(24,480)> -300.0 -173.96857318806974 64.0589597296948 77.0294798648474
# topo slices = (slice(0, 43200, None), slice(18487, 20043, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(480, 961, None) csi= slice(480, 960, None)
# 39 1 <GMesh nj:24 ni:480 shape:(24,480)> -176.6633686070852 -63.336631392914796 64.0589597296948 75.38552532348358
# topo slices = (slice(400, 14000, None), slice(18487, 19846, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(960, 1441, None) csi= slice(960, 1440, None)
# 39 2 <GMesh nj:24 ni:480 shape:(24,480)> -66.03142681193026 60.0 64.0589597296948 77.0294798648474
# topo slices = (slice(13676, 28801, None), slice(18487, 20043, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# sj= slice(960, 985, None) csj= slice(960, 984, None)
# si= slice(0, 481, None) csi= slice(0, 480, None)
# 40 0 <GMesh nj:24 ni:480 shape:(24,480)> -300.0 -169.76650703354284 64.0589597296948 79.62358389187793
# topo slices = (slice(0, 43200, None), slice(18487, 20354, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(480, 961, None) csi= slice(480, 960, None)
# 40 1 <GMesh nj:24 ni:480 shape:(24,480)> -173.96857318806974 -66.03142681193026 64.0589597296948 77.5381883127631
# topo slices = (slice(723, 13677, None), slice(18487, 20104, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(960, 1441, None) csi= slice(960, 1440, None)
# 40 2 <GMesh nj:24 ni:480 shape:(24,480)> -70.23349296645716 60.0 64.0589597296948 79.62358389187793
# topo slices = (slice(13171, 28801, None), slice(18487, 20354, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# sj= slice(984, 1009, None) csj= slice(984, 1008, None)
# si= slice(0, 481, None) csi= slice(0, 480, None)
# 41 0 <GMesh nj:24 ni:480 shape:(24,480)> -300.0 -163.2568789401417 64.0589597296948 82.21768791890844
# topo slices = (slice(0, 43196, None), slice(18487, 20666, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(480, 961, None) csi= slice(480, 960, None)
# 41 1 <GMesh nj:24 ni:480 shape:(24,480)> -169.76650703354284 -70.23349296645716 64.0589597296948 79.53743425639135
# topo slices = (slice(1228, 13172, None), slice(18487, 20344, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(960, 1441, None) csi= slice(960, 1440, None)
# 41 2 <GMesh nj:24 ni:480 shape:(24,480)> -76.74312105985831 60.0 64.0589597296948 82.21768791890844
# topo slices = (slice(12390, 28801, None), slice(18487, 20666, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# sj= slice(1008, 1033, None) csj= slice(1008, 1032, None)
# si= slice(0, 481, None) csi= slice(0, 480, None)
# 42 0 <GMesh nj:24 ni:480 shape:(24,480)> -300.0 -153.2659357393151 64.0589597296948 84.81179194593898
# topo slices = (slice(0, 43197, None), slice(18487, 20977, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(480, 961, None) csi= slice(480, 960, None)
# 42 1 <GMesh nj:24 ni:480 shape:(24,480)> -163.2568789401417 -76.74312105985831 64.0589597296948 81.25597459799884
# topo slices = (slice(2009, 12391, None), slice(18487, 20550, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(960, 1441, None) csi= slice(960, 1440, None)
# 42 2 <GMesh nj:24 ni:480 shape:(24,480)> -86.7340642606849 60.0 64.0589597296948 84.81179194593898
# topo slices = (slice(11191, 28801, None), slice(18487, 20977, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# sj= slice(1032, 1057, None) csj= slice(1032, 1056, None)
# si= slice(0, 481, None) csi= slice(0, 480, None)
# 43 0 <GMesh nj:24 ni:480 shape:(24,480)> -300.0 -138.63777513880885 64.0589597296948 87.40589597296949
# topo slices = (slice(11, 43180, None), slice(18487, 21288, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(480, 961, None) csi= slice(480, 960, None)
# 43 1 <GMesh nj:24 ni:480 shape:(24,480)> -153.2659357393151 -86.7340642606849 64.0589597296948 82.4804079071025
# topo slices = (slice(3208, 11192, None), slice(18487, 20697, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(960, 1441, None) csi= slice(960, 1440, None)
# 43 2 <GMesh nj:24 ni:480 shape:(24,480)> -101.36222486119115 60.0 64.0589597296948 87.40589597296949
# topo slices = (slice(9436, 28801, None), slice(18487, 21288, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# sj= slice(1056, 1081, None) csj= slice(1056, 1080, None)
# si= slice(0, 481, None) csi= slice(0, 480, None)
# 44 0 <GMesh nj:24 ni:480 shape:(24,480)> -300.0 -120.0 64.0589597296948 90.0
# topo slices = (slice(9, 43195, None), slice(18487, 21599, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(480, 961, None) csi= slice(480, 960, None)
# 44 1 <GMesh nj:24 ni:480 shape:(24,480)> -138.63777513880885 -101.36222486119115 64.0589597296948 82.93685446967011
# topo slices = (slice(4963, 9437, None), slice(18487, 20752, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
# si= slice(960, 1441, None) csi= slice(960, 1440, None)
# 44 2 <GMesh nj:24 ni:480 shape:(24,480)> -120.0 60.0 64.0589597296948 90.0
# topo slices = (slice(7200, 28801, None), slice(18487, 21599, None))
# Refine level 0 <GMesh nj:24 ni:480 shape:(24,480)> (0.1758 Mb)
# Refine level 1 <GMesh nj:48 ni:960 shape:(48,960)> (0.7031 Mb)
# Refine level 2 <GMesh nj:96 ni:1920 shape:(96,1920)> (2.8125 Mb)
# Refine level 3 <GMesh nj:192 ni:3840 shape:(192,3840)> (11.2500 Mb)
# Refine level 4 <GMesh nj:384 ni:7680 shape:(384,7680)> (45.0000 Mb)
# Refine level 5 <GMesh nj:768 ni:15360 shape:(768,15360)> (180.0000 Mb)
#     430653ms : Whole workflow
# 1.0 1.0 <-- should both be 1 for full model

# %%
# ax = plt.subplot(111)
# G.plot(ax)

# %%
levels = G.refine_loop( topo_lon[tslices[0]], topo_lat[tslices[1]], resolution_limit=False, fixed_refine_level=5, timers=True )

# %%
# Use nearest neighbor topography to populate the finest grid
levels[-1].project_source_data_onto_target_mesh( topo_lon[tslices[0]], topo_lat[tslices[1]], topo_depth[tslices[1],tslices[0]], timers=True )
h = levels[-1].height # Keep copy

# %%
nx = 2**( len(levels) - 1 )
x = ( np.arange(nx) - ( nx - 1 ) /2 ) * np.sqrt( 12 / ( nx**2 - 1 ) )
print('mean(x) =',x.mean(), 'mean(x^2) =',(x*x).mean())
X, Y = np.meshgrid( x, x )
X, Y = X.reshape(1,nx,1,nx), Y.reshape(1,nx,1,nx)

# %%
# Now recursively coarsen for square
# h = h.reshape(levels[0].nj,nx,levels[0].ni,nx)
# H2 = convol( levels, h, h )
# HX = convol( levels, h, X )
# HY = convol( levels, h, Y )
# H = convol( levels, h, np.ones((1,nx,1,nx)) )
# h2 = H2 - H**2 - HX**2 - HY**2

# %%
H, H2 = rough( levels, h )

# %%
G = levels[0]
plt.pcolormesh( G.lon, G.lat, np.log10(h2), vmin=-3, vmax=6 ); plt.colorbar();

# %%
# Read topo data
with netCDF4.Dataset('/archive/gold/datasets/OM4_025/mosaic.v20170622.unpacked/ocean_topog.nc') as nc:
    print(nc)
    OM4_depth = nc.variables['depth'][:,:].filled(0.)
    OM4_h2 = nc.variables['h2'][:,:].filled(0.)

# %%
plt.pcolormesh( G.lon, G.lat, np.log10( OM4_h2[csj,csi] ), vmin=-3, vmax=6 ); plt.colorbar();

# %%
plt.pcolormesh( G.lon, G.lat, h2 - OM4_h2[csj,csi] ); plt.colorbar();

# %%
# H7, H27 = 1*H, 1*H2
# plt.pcolormesh( G.lon, G.lat, H - H7 ); plt.colorbar();

# %%
with netCDF4.Dataset('mean_h2_topo_3x45.nc','w','clobber') as nc:
    nx = nc.createDimension('nx', Htarg.shape[1])
    ny = nc.createDimension('ny', Htarg.shape[0])
    ntiles = nc.createDimension('ntiles', 1)
    z = nc.createVariable('depth', float, ('ny','nx') )
    z2 = nc.createVariable('h2', float, ('ny','nx') )
    z[:,:] = -Htarg[:,:]
    z2[:,:] = H2targ[:,:]
