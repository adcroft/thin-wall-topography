# %%
import netCDF4
import numpy
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
H=netCDF4.Dataset('ETOPO5.nc').variables['elevation'][:,:]
x=netCDF4.Dataset('ETOPO5.nc').variables['lon'][:]
y=netCDF4.Dataset('ETOPO5.nc').variables['lat'][:]

# %%
plt.pcolormesh(x,y,H);
# Out:
# C:\Users\User\Anaconda3\envs\mypy3.4\lib\site-packages\matplotlib\collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
